# %%
# Dependencies
import requests
from pprint import pprint
from config_om import api_key
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import json
import csv

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
query = "data science"

# Search for articles published between a begin and end date
begin_date = "20100101"
end_date = "20101231"
fq="education"

query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}&fq={fq}"
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=HjrcyWsWyOsIQjLt6PGC5PuESKSvZiCj&q=data science&begin_date=20100101&end_date=20101231&fq=education'

# %%
#articles = requests.get(query_url).json()
#['response']['docs']
#articles
r = requests.get(query_url)

json_data = json.loads(r.text)

# %%
json_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Lesson Plan | Understanding the scientific value of citizen reports of wildlife hurt or killed in vehicle collisions.',
#     'web_url': 'https://learning.blogs.nytimes.com/2010/09/15/on-the-road-analyzing-citizen-science-reports-on-roadkill/',
#     'snippet': 'Lesson Plan | Understanding the scientific value of citizen reports of wildlife hurt or killed in vehicle collisions.',
#     'lead_paragraph': 'Overview | What can we learn from animals that have accidentally been killed as a result of human activity? In this lesson, students use a map to navigate local roads from the perspective of a common animal. Then they analyze geographic data collected from animals killed in motor vehicle collisions and propose ways to reduce them. They learn how to analyze the layers of data included in interactive maps, think critically about the data and apply what they have learned to suggesting ways to improve roadway safety for wildlife. ',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'On the Road: Analyzing Citizen Science Reports on Roadkill',
#      'kicker': 'The Learning Network',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-09-15T19:45:00+0000',
#     'document_type': 'article',
#     'news_desk': '',
#     'section_name': 'Education',
#     'byline': {'original': 'By Jennifer Cutraro and Holly Epstein Ojalvo',
#      'person': [{'firstname': 'Jennifer',
#        'middlename': None,
#        'lastname': 'Cutraro',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1},
#       {'firstname': 'Holly',
#        'middlename': 'Epstein',
#        'lastname': 'Ojalvo',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 2}],
#      'organization': None},
#     '_id': 'nyt://article/b492a99e-4df3-533b-adb0-36489a112ea8',
#     'word_count': 1356,
#     'uri': 'nyt://article/b492a99e-4df3-533b-adb0-36489a112ea8'},
#    {'abstract': 'Teachers and students are asked to weigh in on classroom struggles over climate change.',
#     'web_url': 'https://dotearth.blogs.nytimes.com/2010/03/04/the-classroom-as-science-hot-zone/',
#     'snippet': 'Teachers and students are asked to weigh in on classroom struggles over climate change.',
#     'lead_paragraph': 'Too often, the classroom has been a battleground in which science loses out to ideology — either directly, as with fights to equate biblical accounts of creation with research illuminating natural selection, or indirectly, when fears of such fights cause teachers or administrators in a more subtle way to skip or skim over science that has big implications for society.',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'The Classroom as Science Hot Zone',
#      'kicker': 'Dot Earth',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-03-04T18:43:50+0000',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'section_name': 'Science',
#     'byline': {'original': 'By Andrew C. Revkin',
#      'person': [{'firstname': 'Andrew',
#        'middlename': 'C.',
#        'lastname': 'Revkin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     '_id': 'nyt://article/8273452f-abef-5524-b2ab-6bfdbb163556',
#     'word_count': 765,
#     'uri': 'nyt://article/8273452f-abef-5524-b2ab-6bfdbb163556'},
#    {'abstract': 'Researchers and communications experts debate how to fight attacks on climate science.',
#     'web_url': 'https://dotearth.blogs.nytimes.com/2010/03/08/should-scientists-fight-heat-or-stick-to-data/',
#     'snippet': 'Researchers and communications experts debate how to fight attacks on climate science.',
#     'lead_paragraph': 'Some leading lights in environmental science have been pushing their colleagues, and institutions like the National Academies, to come out swinging against the ongoing barrage of assaults from organized opponents of restrictions on greenhouse gases and climate skeptics/contrarians/denialists/realists (pick your label depending on your worldview).',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Should Scientists Fight Heat or Stick to Data?',
#      'kicker': 'Dot Earth',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-03-08T16:51:48+0000',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'section_name': 'Science',
#     'byline': {'original': 'By Andrew C. Revkin',
#      'person': [{'firstname': 'Andrew',
#        'middlename': 'C.',
#        'lastname': 'Revkin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     '_id': 'nyt://article/b404dd53-0250-5e50-ae4a-29c2ee84e588',
#     'word_count': 1677,
#     'uri': 'nyt://article/b404dd53-0250-5e50-ae4a-29c2ee84e588'},
#    {'abstract': 'Taking Questions: Robert Gebeloff, who has been working on an extensive database of New York education statistics, responds to readers.',
#     'web_url': 'https://cityroom.blogs.nytimes.com/2010/04/30/answers-about-new-york-school-data-part-3/',
#     'snippet': 'Taking Questions: Robert Gebeloff, who has been working on an extensive database of New York education statistics, responds to readers.',
#     'lead_paragraph': 'Following is the third and final set of responses from Robert Gebeloff, a computer-assisted journalist with an expertise in education who has been working on an extensive database of New York education statistics.',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Answers About New York School Data, Part 3',
#      'kicker': 'City Room',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-04-30T21:58:44+0000',
#     'document_type': 'article',
#     'news_desk': 'Metro',
#     'section_name': 'New York',
#     'byline': {'original': 'By The New York Times',
#      'person': [],
#      'organization': 'The New York Times'},
#     '_id': 'nyt://article/7b037c27-5891-505a-9635-b52183c06fef',
#     'word_count': 831,
#     'uri': 'nyt://article/7b037c27-5891-505a-9635-b52183c06fef'},
#    {'abstract': 'This summer, would-be scientists and firefly enthusiasts can put their fascination with the glow bug to use by counting fireflies to help scientists with their research.',
#     'web_url': 'https://green.blogs.nytimes.com/2010/04/27/for-summer-sentinels-a-firefly-count/',
#     'snippet': 'This summer, would-be scientists and firefly enthusiasts can put their fascination with the glow bug to use by counting fireflies to help scientists with their research.',
#     'lead_paragraph': 'I have fond childhood memories of counting fireflies on summer nights in Ohio.',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'For Summer Sentinels, a Firefly Count',
#      'kicker': 'Green',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-04-27T18:26:36+0000',
#     'document_type': 'article',
#     'news_desk': '',
#     'section_name': 'Science',
#     'subsection_name': 'Environment',
#     'byline': {'original': 'By Sindya N. Bhanoo',
#      'person': [{'firstname': 'Sindya',
#        'middlename': 'N.',
#        'lastname': 'Bhanoo',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     '_id': 'nyt://article/1b48b723-2afc-5ac0-a472-3f391cee8294',
#     'word_count': 391,
#     'uri': 'nyt://article/1b48b723-2afc-5ac0-a472-3f391cee8294'},
#    {'abstract': 'The lesson of CFC’s and the hole in the ozone is that patient, observant, careful and continuous science can make a difference.',
#     'web_url': 'https://www.nytimes.com/2010/05/15/opinion/15sat4.html',
#     'snippet': 'The lesson of CFC’s and the hole in the ozone is that patient, observant, careful and continuous science can make a difference.',
#     'lead_paragraph': 'Twenty-five years ago this month, a small team of scientists discovered that the ozone layer above their Antarctic station was thinning more and more every spring. The layer protects life on earth from the sun’s ultraviolet light. The response to that discovery is a rare, happy environmental morality tale. ',
#     'print_section': 'A',
#     'print_page': '18',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Hole in the Spring Sky',
#      'kicker': 'Editorial',
#      'content_kicker': None,
#      'print_headline': 'A Hole in the Spring Sky',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'ANTARCTIC REGIONS',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Environment', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Ozone', 'rank': 3, 'major': 'N'}],
#     'pub_date': '2010-05-15T00:39:24+0000',
#     'document_type': 'article',
#     'news_desk': 'Editorial',
#     'section_name': 'Opinion',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Editorial',
#     '_id': 'nyt://article/41fda83f-8a78-5d3f-adec-8e113c25e833',
#     'word_count': 309,
#     'uri': 'nyt://article/41fda83f-8a78-5d3f-adec-8e113c25e833'},
#    {'abstract': 'A recent revelation that the works of one scholar put a little-known university into a top league table is embarrassing for the business of academic ratings.',
#     'web_url': 'https://www.nytimes.com/2010/11/15/education/15iht-educLede15.html',
#     'snippet': 'A recent revelation that the works of one scholar put a little-known university into a top league table is embarrassing for the business of academic ratings.',
#     'lead_paragraph': 'LONDON — For institutions that regularly make the Top 10, the autumn announcement of university rankings is an occasion for quiet self-congratulation.',
#     'source': 'International Herald Tribune',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-articleLarge.jpg',
#       'height': 350,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 350},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-jumbo.jpg',
#       'height': 680,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-popup.jpg',
#       'height': 432,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-articleInline.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-sfSpan.jpg',
#       'height': 260,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2010/11/15/education/15iht-euclede1_span/15iht-euclede1_span-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'}],
#     'headline': {'main': 'Questionable Science Behind Academic Rankings',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'The Questionable Science Behind Academic Rankings',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Education (Secondary)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Colleges and Universities',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '2010-11-14T22:43:45+0000',
#     'document_type': 'article',
#     'news_desk': 'Business',
#     'section_name': 'Education',
#     'byline': {'original': 'By D.D. GUTTENPLAN',
#      'person': [],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/eff2cb76-1cf8-566e-9675-01551b472f7b',
#     'word_count': 1205,
#     'uri': 'nyt://article/eff2cb76-1cf8-566e-9675-01551b472f7b'},
#    {'abstract': 'China is leaping forward in the sciences, but academic fraud and limited Web access are hurdles.',
#     'web_url': 'https://roomfordebate.blogs.nytimes.com/2010/01/18/will-china-achieve-science-supremacy/',
#     'snippet': 'China is leaping forward in the sciences, but academic fraud and limited Web access are hurdles.',
#     'lead_paragraph': 'A recent Times article described how China is stepping up efforts to lure home the top Chinese scholars who live and work abroad. The nation is already second only to the United States in the volume of scientific papers published, and it has, as Thomas Friedman pointed out, more students in technical colleges and universities than any other country. ',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Will China Achieve Science Supremacy?',
#      'kicker': 'Room for Debate',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-01-18T23:45:29+0000',
#     'document_type': 'article',
#     'news_desk': '',
#     'section_name': 'Opinion',
#     'byline': {'original': 'By The Editors',
#      'person': [],
#      'organization': 'The Editors'},
#     '_id': 'nyt://article/cf8cdc69-f846-5fa4-a135-135df4332795',
#     'word_count': 2742,
#     'uri': 'nyt://article/cf8cdc69-f846-5fa4-a135-135df4332795'},
#    {'abstract': 'Taking Questions: Robert Gebeloff, who has been working on an extensive database of New York education statistics, responds to readers.',
#     'web_url': 'https://cityroom.blogs.nytimes.com/2010/04/29/answers-about-new-york-school-data-part-2/',
#     'snippet': 'Taking Questions: Robert Gebeloff, who has been working on an extensive database of New York education statistics, responds to readers.',
#     'lead_paragraph': 'Following is the second set of responses from Robert Gebeloff, a computer-assisted journalist with an expertise in education who has been working on an extensive database of New York education statistics.',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Answers About New York School Data, Part 2',
#      'kicker': 'City Room',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2010-04-29T20:54:04+0000',
#     'document_type': 'article',
#     'news_desk': 'Metro',
#     'section_name': 'New York',
#     'byline': {'original': 'By The New York Times',
#      'person': [],
#      'organization': 'The New York Times'},
#     '_id': 'nyt://article/823612cb-fc30-580e-8f9f-227181dd70f6',
#     'word_count': 825,
#     'uri': 'nyt://article/823612cb-fc30-580e-8f9f-227181dd70f6'},
#    {'abstract': 'Building on decades of research, scientists and animators are recreating in detail the complex inner machinery of living cells.',
#     'web_url': 'https://www.nytimes.com/2010/11/16/science/16animate.html',
#     'snippet': 'Building on decades of research, scientists and animators are recreating in detail the complex inner machinery of living cells.',
#     'lead_paragraph': 'When Robert A. Lue considers the “Star Wars” Death Star, his first thought is not of outer space, but inner space.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-articleLarge.jpg',
#       'height': 315,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2010/11/16/science/16animate1/16animate1-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 315},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-blog480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-jumbo.jpg',
#       'height': 576,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-popup.jpg',
#       'height': 366,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-articleInline.jpg',
#       'height': 107,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-sfSpan.jpg',
#       'height': 250,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2010/11/16/science/16animate1/16animate1-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2010/11/16/science/16animate1/16animate1-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'}],
#     'headline': {'main': 'Where Cinema and Biology Meet',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Where Cinema and Biology Meet',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Biology and Biochemistry',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'ANIMATED FILMS', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Science and Technology',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2010-11-15T21:33:38+0000',
#     'document_type': 'article',
#     'news_desk': 'Science',
#     'section_name': 'Science',
#     'byline': {'original': 'By Erik Olsen',
#      'person': [{'firstname': 'Erik',
#        'middlename': None,
#        'lastname': 'Olsen',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4188f939-d80b-5963-bb24-86f859844a26',
#     'word_count': 1144,
#     'uri': 'nyt://article/4188f939-d80b-5963-bb24-86f859844a26'}],
#   'meta': {'hits': 235, 'offset': 0, 'time': 263}}}

# %%
df = pd.DataFrame(json_data)

# %%
df
# Out:
#      status                                          copyright  \
# docs     OK  Copyright (c) 2020 The New York Times Company....
# meta     OK  Copyright (c) 2020 The New York Times Company....
#
#                                                response
# docs  [{'abstract': 'Lesson Plan | Understanding the...
# meta            {'hits': 235, 'offset': 0, 'time': 263}
